# %%
import warnings
warnings.filterwarnings('ignore')

from __code.step2_slice_ccd_or_timepix_images import Step2SliceCcdOrTimePixImages

from __code import system

system.System.select_working_dir(ipts="IPTS-36573", instrument="VENUS")
from __code.__all import custom_style
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# logging file: /SNS/VENUS/shared/log/system_j35.log
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(index=2, la…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px;
#     border-style: solid;
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
# </style>

# %% [markdown]
# # Select config file

# %%
o_step2 = Step2SliceCcdOrTimePixImages(system=system)
o_step2.select_config_file()
# Out:
# logging file: /SNS/VENUS/shared/log/step2_slice_ccd_or_timepix_images_j35.log
# VBox(children=(Label(value='Select configuration file ...', layout=Layout(width='100%')), VBox(children=(HBox(…

# %% [markdown]
# # Load images and crop if needed

# %%
o_step2.load_and_crop()
# Out:
# interactive(children=(IntSlider(value=0, description='image_index', layout=Layout(width='50%'), max=29), IntRa…

# %% [markdown]
# # Select how to sub-divide the reconstruction

# %%
o_step2.select_range_of_slices()
# Out:
# interactive(children=(IntSlider(value=0, description='image_index', layout=Layout(width='50%'), max=29), IntRa…

# %% [markdown]
# # Reconstruction algorithms available

# %%
o_step2.reconstruction_algorithm_selection()
# Out:
# HTML(value='<font size=5 color=blue>Select reconstruction algorithm(s)</font>')
# HTML(value='<font size=3 color=black>Multiple selection allowed by <b>CTRL+click</b></font>')
# VBox(children=(SelectMultiple(index=(5,), options=('algotom_fbp', 'algotom_gridrec', 'astra_fbp', 'mbirjax', '…

# %% [markdown]
# # Create new config file(s)

# %% [markdown]
# ### What type of json do you want to create?
#
# If you decide to subdivide your reconstruction, you will have the choice to create one script or several script you can can in parallel manually

# %%
o_step2.select_json_type_you_want_to_create()
# Out:
# RadioButtons(description='Json types:', layout=Layout(width='50%'), options=('1 json (reconstruction will run …

# %% [markdown]
# ### rename the configuration files ?

# %%
o_step2.rename_or_not_configuration_files()
# Out:
# Checkbox(value=False, description='Rename base configuration file', indent=False, layout=Layout(width='50%'))
# HBox(children=(Label(value='New basename:', layout=Layout(width='100px')), Text(value='step2_slice_ccd_or_time…
# HBox(children=(Label(value='Old basename:', layout=Layout(width='100px')), Label(value='step2_slice_ccd_or_tim…

# %% [markdown]
# ### Create the final json file(s)

# %%
o_step2.export_config_file()
# Out:
# Next and final step. Launch the following script from the command line:
# config file name: <font color='blue'>step2_slice_ccd_or_timepix_images_05m_20d_2026y_22h_25mn.json</font>
# <font color='green'>/SNS/VENUS/IPTS-36573/shared/processed_data/hassina/reconstruction_tomopy/run_reconstruction_05m_20d_2026y_22h_25mn.sh</font>

# %%
# !pixi list
# Out:
# Package                        Version            Build                    Size        Kind   Source
# _openmp_mutex                  4.5                20_gnu                   28.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# _python_abi3_support           1.0                hd8ed1ab_2               8 KiB       conda  https://conda.anaconda.org/conda-forge/
# absl_py                        2.4.0                                                   pypi
# algotom                        1.7.0              pyhd8ed1ab_0             88.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# annotated-types                0.7.0              pyhd8ed1ab_1             17.7 KiB    conda  https://conda.anaconda.org/conda-forge/
# anyio                          4.13.0             pyhcf101f3_0             143.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# aom                            3.9.1              hac33072_0               2.6 MiB     conda  https://conda.anaconda.org/conda-forge/
# argon2-cffi                    25.1.0             pyhd8ed1ab_0             18.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# argon2-cffi-bindings           25.1.0             py313h07c4f96_2          35.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# arrow                          1.4.0              pyhcf101f3_0             111.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# astra-toolbox                  2.4.1              py313heeb91a5_0          387.8 KiB   conda  https://conda.anaconda.org/conda-forge/
# astropy                        6.1.7              py313ha014f3b_0          8.9 MiB     conda  https://conda.anaconda.org/conda-forge/
# astropy-iers-data              0.2026.5.4.1.4.54  pyhd8ed1ab_0             1.2 MiB     conda  https://conda.anaconda.org/conda-forge/
# asttokens                      3.0.1              pyhd8ed1ab_0             28.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# async-lru                      2.3.0              pyhcf101f3_0             22.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# attrs                          26.1.0             pyhcf101f3_0             63.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# aws-c-auth                     0.10.1             ha62d5e7_3               131.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# aws-c-cal                      0.9.13             h2c9d079_1               54.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# aws-c-common                   0.12.6             hb03c661_0               234 KiB     conda  https://conda.anaconda.org/conda-forge/
# aws-c-compression              0.3.2              h8b1a151_0               21.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# aws-c-http                     0.10.13            h4bacb7b_0               220.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# aws-c-io                       0.26.3             h692f434_1               177.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# aws-c-s3                       0.12.2             he6ee468_1               149.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# aws-c-sdkutils                 0.2.4              h8b1a151_4               58 KiB      conda  https://conda.anaconda.org/conda-forge/
# aws-checksums                  0.2.10             h8b1a151_0               99.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# babel                          2.18.0             pyhcf101f3_1             7.3 MiB     conda  https://conda.anaconda.org/conda-forge/
# backports.zstd                 1.4.0              py313h18e8e13_0          235.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# beautifulsoup4                 4.14.3             pyha770c72_0             88.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# bleach                         6.3.0              pyhcf101f3_1             138.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# bleach-with-css                6.3.0              hbca2aae_1               4.3 KiB     conda  https://conda.anaconda.org/conda-forge/
# blosc                          1.21.6             he440d0b_1               47.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# brotli                         1.2.0              hed03a55_1               19.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# brotli-bin                     1.2.0              hb03c661_1               20.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# brotli-python                  1.2.0              py313hf159716_1          359.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# brunsli                        0.1                hd1e3526_2               164.6 KiB   conda  https://conda.anaconda.org/conda-forge/
# bzip2                          1.0.8              hda65f42_9               254.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# c-ares                         1.34.6             hb03c661_0               203 KiB     conda  https://conda.anaconda.org/conda-forge/
# c-blosc2                       3.0.2              hc31b594_0               366.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# ca-certificates                2026.4.22          hbd8a1cb_0               128 KiB     conda  https://conda.anaconda.org/conda-forge/
# cached-property                1.5.2              hd8ed1ab_1               4 KiB       conda  https://conda.anaconda.org/conda-forge/
# cached_property                1.5.2              pyha770c72_1             10.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# certifi                        2026.4.22          pyhd8ed1ab_0             132.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# cffi                           2.0.0              py313hf46b229_1          291.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# charls                         2.4.3              hecca717_0               158 KiB     conda  https://conda.anaconda.org/conda-forge/
# charset-normalizer             3.4.7              pyhd8ed1ab_0             57.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# chex                           0.1.91                                                  pypi
# colorama                       0.4.6              pyhd8ed1ab_1             26.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# comm                           0.2.3              pyhe01879c_0             14.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# configparser                   7.2.0                                                   pypi
# contourpy                      1.3.3              py313hc8edb43_4          314.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# cpython                        3.13.13            py313hd8ed1ab_100        47.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# cycler                         0.12.1             pyhcf101f3_2             14.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# dav1d                          1.2.1              hd590300_0               742.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# debugpy                        1.8.20             py313h5d5ffb9_0          2.7 MiB     conda  https://conda.anaconda.org/conda-forge/
# decorator                      5.2.1              pyhd8ed1ab_0             13.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# defusedxml                     0.7.1              pyhd8ed1ab_0             23.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# dm_pix                         0.4.4                                                   pypi
# easygui                        0.98.3                                                  pypi
# exceptiongroup                 1.3.1              pyhd8ed1ab_0             20.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# executing                      2.2.1              pyhd8ed1ab_0             30 KiB      conda  https://conda.anaconda.org/conda-forge/
# fftw                           3.3.11             nompi_h3b011a4_100       2.1 MiB     conda  https://conda.anaconda.org/conda-forge/
# filelock                       3.29.0                                                  pypi
# fonttools                      4.62.1             py313h3dea7bd_0          2.8 MiB     conda  https://conda.anaconda.org/conda-forge/
# fqdn                           1.5.1              pyhd8ed1ab_1             16.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# freetype                       2.14.3             ha770c72_0               169.8 KiB   conda  https://conda.anaconda.org/conda-forge/
# gdown                          6.0.0                                                   pypi
# giflib                         5.2.2              hd590300_0               75.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# h11                            0.16.0             pyhcf101f3_1             38.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# h2                             4.3.0              pyhcf101f3_0             93.7 KiB    conda  https://conda.anaconda.org/conda-forge/
# h5py                           3.16.0             nompi_py313h22c32d4_102  1.3 MiB     conda  https://conda.anaconda.org/conda-forge/
# hatchling                      1.29.0                                                  pypi
# hdf5                           2.1.0              nompi_h87a9417_105       4.5 MiB     conda  https://conda.anaconda.org/conda-forge/
# hpack                          4.1.0              pyhd8ed1ab_0             30 KiB      conda  https://conda.anaconda.org/conda-forge/
# html5lib                       1.1                                                     pypi
# httpcore                       1.0.9              pyh29332c3_0             48.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# httpx                          0.28.1             pyhd8ed1ab_0             61.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# hyperframe                     6.1.0              pyhd8ed1ab_0             17 KiB      conda  https://conda.anaconda.org/conda-forge/
# idna                           3.13               pyhcf101f3_0             57.7 KiB    conda  https://conda.anaconda.org/conda-forge/
# imagecodecs                    2026.3.6           py313h7b635f6_3          2 MiB       conda  https://conda.anaconda.org/conda-forge/
# imageio                        2.37.0             pyhfb79c49_0             286.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# importlib-metadata             8.8.0              pyhcf101f3_0             33.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# importlib_resources            7.1.0              pyhd8ed1ab_0             34 KiB      conda  https://conda.anaconda.org/conda-forge/
# iniconfig                      2.3.0              pyhd8ed1ab_0             13.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# intel_cmplr_lib_ur             2026.0.0                                                pypi
# intel_openmp                   2026.0.0                                                pypi
# ipykernel                      7.2.0              pyha191276_1             130.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# ipympl                         0.9.8              pyhcf101f3_0             235.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# ipython                        9.12.0             pyhecfbec7_0             634.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# ipython_pygments_lexers        1.1.1              pyhd8ed1ab_0             13.7 KiB    conda  https://conda.anaconda.org/conda-forge/
# ipywidgets                     8.1.8              pyhd8ed1ab_0             111.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# isoduration                    20.11.0            pyhd8ed1ab_1             19.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# jax                            0.10.0                                                  pypi
# jax_cuda13_pjrt                0.10.0                                                  pypi
# jax_cuda13_plugin              0.10.0                                                  pypi
# jaxlib                         0.10.0                                                  pypi
# jedi                           0.19.2             pyhd8ed1ab_1             823.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# jinja2                         3.1.6              pyhcf101f3_1             117.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# joblib                         1.5.3              pyhd8ed1ab_0             221.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# json5                          0.14.0             pyhd8ed1ab_0             33.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# jsonpointer                    3.1.1              pyhcf101f3_0             13.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# jsonschema                     4.26.0             pyhcf101f3_0             80.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# jsonschema-specifications      2025.9.1           pyhcf101f3_0             18.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# jsonschema-with-format-nongpl  4.26.0             hcf101f3_0               4.6 KiB     conda  https://conda.anaconda.org/conda-forge/
# jupyter                        1.1.1              pyhd8ed1ab_1             8.7 KiB     conda  https://conda.anaconda.org/conda-forge/
# jupyter-lsp                    2.3.1              pyhcf101f3_0             60.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# jupyter_client                 8.8.0              pyhcf101f3_0             110.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# jupyter_console                6.6.3              pyhd8ed1ab_1             26.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# jupyter_core                   5.9.1              pyhc90fa1f_0             64 KiB      conda  https://conda.anaconda.org/conda-forge/
# jupyter_events                 0.12.1             pyhcf101f3_0             23.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# jupyter_server                 2.18.2             pyhcf101f3_0             352.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# jupyter_server_terminals       0.5.4              pyhcf101f3_0             21.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# jupyterlab                     4.5.7              pyhd8ed1ab_0             8.5 MiB     conda  https://conda.anaconda.org/conda-forge/
# jupyterlab_pygments            0.3.0              pyhd8ed1ab_2             18.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# jupyterlab_server              2.28.0             pyhcf101f3_0             50.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# jupyterlab_widgets             3.0.16             pyhcf101f3_1             211.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# jxrlib                         1.1                hd590300_3               233.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# keyutils                       1.6.3              hb9d3cd8_0               130.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# kiwisolver                     1.5.0              py313hc8edb43_0          75.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# krb5                           1.22.2             ha1258a1_0               1.3 MiB     conda  https://conda.anaconda.org/conda-forge/
# lark                           1.3.1              pyhd8ed1ab_0             92.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# lazy-loader                    0.5                pyhd8ed1ab_0             14.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# lcms2                          2.19.1             h0c24ade_0               245.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# ld_impl_linux-64               2.45.1             default_hbd61a6d_102     710.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# lerc                           4.1.0              hdb68285_0               255.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# libaec                         1.1.5              h088129d_0               35.7 KiB    conda  https://conda.anaconda.org/conda-forge/
# libastra                       2.4.1              hd22cb3e_0               678.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# libavif16                      1.4.1              hcfa2d63_0               145.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# libblas                        3.11.0             6_h4a7cf45_openblas      18.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# libbrotlicommon                1.2.0              hb03c661_1               78.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# libbrotlidec                   1.2.0              hb03c661_1               33.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# libbrotlienc                   1.2.0              hb03c661_1               291.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# libcblas                       3.11.0             6_h0358290_openblas      18.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# libcurl                        8.20.0             hcf29cc6_0               457.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# libdeflate                     1.25               h17f619e_0               71.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# libedit                        3.1.20250104       pl5321h7949ede_0         131.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# libev                          4.33               hd590300_2               110.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# libexpat                       2.8.0              hecca717_0               75.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# libffi                         3.5.2              h3435931_0               57.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# libfreetype                    2.14.3             ha770c72_0               7.9 KiB     conda  https://conda.anaconda.org/conda-forge/
# libfreetype6                   2.14.3             h73754d4_0               375.6 KiB   conda  https://conda.anaconda.org/conda-forge/
# libgcc                         15.2.0             he0feb66_18              1017.4 KiB  conda  https://conda.anaconda.org/conda-forge/
# libgcc-ng                      15.2.0             h69a702a_18              26.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# libgfortran                    15.2.0             h69a702a_18              26.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# libgfortran5                   15.2.0             h68bc16d_18              2.4 MiB     conda  https://conda.anaconda.org/conda-forge/
# libgomp                        15.2.0             he0feb66_18              589.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# libhwy                         1.4.0              h10be129_0               1.4 MiB     conda  https://conda.anaconda.org/conda-forge/
# libjpeg-turbo                  3.1.4.1            hb03c661_0               619 KiB     conda  https://conda.anaconda.org/conda-forge/
# libjxl                         0.11.2             h174a0a3_1               1.8 MiB     conda  https://conda.anaconda.org/conda-forge/
# liblapack                      3.11.0             6_h47877c9_openblas      18.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# liblzma                        5.8.3              hb03c661_0               110.8 KiB   conda  https://conda.anaconda.org/conda-forge/
# libmpdec                       4.0.0              hb03c661_1               90.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# libnghttp2                     1.68.1             h877daf1_0               647.8 KiB   conda  https://conda.anaconda.org/conda-forge/
# libopenblas                    0.3.32             pthreads_h94d23a6_0      5.7 MiB     conda  https://conda.anaconda.org/conda-forge/
# libpng                         1.6.58             h421ea60_0               310.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# libsodium                      1.0.21             h280c20c_3               271.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# libsqlite                      3.53.1             h0c1763c_0               932.6 KiB   conda  https://conda.anaconda.org/conda-forge/
# libssh2                        1.11.1             hcf80075_0               297.6 KiB   conda  https://conda.anaconda.org/conda-forge/
# libstdcxx                      15.2.0             h934c35e_18              5.6 MiB     conda  https://conda.anaconda.org/conda-forge/
# libstdcxx-ng                   15.2.0             hdf11a46_18              26.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# libtiff                        4.7.1              h9d88235_1               425.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# libtomo                        1.15.3             h1234567_1               82.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# libuuid                        2.42               h5347b49_0               39.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# libwebp-base                   1.6.0              hd42ef1d_0               419 KiB     conda  https://conda.anaconda.org/conda-forge/
# libxcb                         1.17.0             h8a09558_0               386.6 KiB   conda  https://conda.anaconda.org/conda-forge/
# libzlib                        1.3.2              h25fd6f3_2               62.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# libzopfli                      1.0.3              h9c3ff4c_0               164.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# llvmlite                       0.47.0             py313hdd307be_1          32.5 MiB    conda  https://conda.anaconda.org/conda-forge/
# loguru                         0.7.3              pyh707e725_0             58.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# lxml                           6.1.0                                                   pypi
# lz4-c                          1.10.0             h5888daf_1               163.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# markupsafe                     3.0.3              py313h3dea7bd_1          25.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# matplotlib-base                3.10.9             py313h683a580_0          7.9 MiB     conda  https://conda.anaconda.org/conda-forge/
# matplotlib-inline              0.2.1              pyhd8ed1ab_0             14.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# mbirjax                        0.6.15                                                  pypi
# mistune                        3.2.1              pyhcf101f3_0             72.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# mkl                            2026.0.0                                                pypi
# mkl_fft                        2.2.0                                                   pypi
# ml_dtypes                      0.5.4                                                   pypi
# munkres                        1.1.4              pyhd8ed1ab_1             15.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# narwhals                       2.20.0             pyhcf101f3_0             277 KiB     conda  https://conda.anaconda.org/conda-forge/
# nbclient                       0.10.4             pyhd8ed1ab_0             27.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# nbconvert-core                 7.17.1             pyhcf101f3_0             197.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# nbformat                       5.10.4             pyhd8ed1ab_1             98.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# ncurses                        6.6                hdb14827_0               897.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# nest-asyncio                   1.6.0              pyhd8ed1ab_1             11.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# networkx                       3.6.1              pyhcf101f3_0             1.5 MiB     conda  https://conda.anaconda.org/conda-forge/
# neutronbraggedge               2.0.6                                                   pypi
# nomkl                          1.0                h5ca1d4c_0               3.8 KiB     conda  https://conda.anaconda.org/conda-forge/
# notebook                       7.5.6              pyhcf101f3_1             9.6 MiB     conda  https://conda.anaconda.org/conda-forge/
# notebook-shim                  0.2.4              pyhd8ed1ab_1             16.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# numba                          0.65.1             py313h5dce7c4_0          5.5 MiB     conda  https://conda.anaconda.org/conda-forge/
# numexpr                        2.14.1             py313h24ae7f9_101        209.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# numpy                          2.4.3              py313hf6604e3_0          8.4 MiB     conda  https://conda.anaconda.org/conda-forge/
# nvidia_cublas                  13.4.1.1                                                pypi
# nvidia_cuda_cccl               13.2.75                                                 pypi
# nvidia_cuda_crt                13.2.78                                                 pypi
# nvidia_cuda_cupti              13.2.75                                                 pypi
# nvidia_cuda_nvcc               13.2.78                                                 pypi
# nvidia_cuda_nvrtc              13.2.78                                                 pypi
# nvidia_cuda_runtime            13.2.75                                                 pypi
# nvidia_cudnn_cu13              9.21.1.3                                                pypi
# nvidia_cufft                   12.2.0.46                                               pypi
# nvidia_cusolver                12.2.0.1                                                pypi
# nvidia_cusparse                12.7.10.1                                               pypi
# nvidia_nccl_cu13               2.30.4                                                  pypi
# nvidia_nvjitlink               13.2.78                                                 pypi
# nvidia_nvshmem_cu13            3.6.5                                                   pypi
# nvidia_nvvm                    13.2.78                                                 pypi
# olefile                        0.47                                                    pypi
# onemkl_license                 2026.0.0                                                pypi
# opencv_python                  4.13.0.92                                               pypi
# openjpeg                       2.5.4              h55fea9a_0               347.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# openjph                        0.27.0             h8d634f6_0               276 KiB     conda  https://conda.anaconda.org/conda-forge/
# openssl                        3.6.2              h35e630c_0               3 MiB       conda  https://conda.anaconda.org/conda-forge/
# opt_einsum                     3.4.0                                                   pypi
# osqp                           1.1.1                                                   pypi
# overrides                      7.7.0              pyhd8ed1ab_1             29.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# packaging                      26.2               pyhc364b38_0             89.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# pandas                         2.3.3              py313h08cd8bf_2          14.2 MiB    conda  https://conda.anaconda.org/conda-forge/
# pandocfilters                  1.5.0              pyhd8ed1ab_0             11.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# parso                          0.8.7              pyhcf101f3_0             80.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# pathspec                       1.1.1                                                   pypi
# pexpect                        4.9.0              pyhd8ed1ab_1             52.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# pillow                         12.2.0             py313h80991f8_0          1 MiB       conda  https://conda.anaconda.org/conda-forge/
# pip                            26.1.1             pyh145f28c_0             1.1 MiB     conda  https://conda.anaconda.org/conda-forge/
# platformdirs                   4.9.6              pyhcf101f3_0             25.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# plotly                         6.6.0              pyhd8ed1ab_0             5 MiB       conda  https://conda.anaconda.org/conda-forge/
# pluggy                         1.6.0              pyhf9edf01_1             25.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# prometheus_client              0.25.0             pyhd8ed1ab_0             55.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# prompt-toolkit                 3.0.52             pyha770c72_0             267.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# prompt_toolkit                 3.0.52             hd8ed1ab_0               7 KiB       conda  https://conda.anaconda.org/conda-forge/
# psutil                         6.1.1              py313h536fd9c_0          483.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# pthread-stubs                  0.4                hb9d3cd8_1002            8.1 KiB     conda  https://conda.anaconda.org/conda-forge/
# ptyprocess                     0.7.0              pyhd8ed1ab_1             19 KiB      conda  https://conda.anaconda.org/conda-forge/
# pure_eval                      0.2.3              pyhd8ed1ab_1             16.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# pycparser                      2.22               pyh29332c3_1             107.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# pydantic                       2.13.3             pyhcf101f3_0             338.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# pydantic-core                  2.46.3             py313h843e2db_0          1.8 MiB     conda  https://conda.anaconda.org/conda-forge/
# pyerfa                         2.0.1.5            py310h32771cd_2          288.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# pygments                       2.20.0             pyhd8ed1ab_0             872.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# pyparsing                      3.3.2              pyhcf101f3_0             108.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# pysocks                        1.7.1              pyha55dd90_7             20.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# pytest                         9.0.3              pyhc364b38_1             293 KiB     conda  https://conda.anaconda.org/conda-forge/
# python                         3.13.13            h6add32d_100_cp313       35.6 MiB    conda  https://conda.anaconda.org/conda-forge/
# python-dateutil                2.9.0.post0        pyhe01879c_2             227.8 KiB   conda  https://conda.anaconda.org/conda-forge/
# python-fastjsonschema          2.21.2             pyhe01879c_0             238.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# python-gil                     3.13.13            h4df99d1_100             47.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# python-json-logger             3.2.1              pyh332efcf_0             18.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# python-tzdata                  2026.2             pyhd8ed1ab_0             143.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# python_abi                     3.13               8_cp313                  6.8 KiB     conda  https://conda.anaconda.org/conda-forge/
# pytz                           2026.2             pyhcf101f3_0             197 KiB     conda  https://conda.anaconda.org/conda-forge/
# pywavelets                     1.9.0              py313h29aa505_2          3.5 MiB     conda  https://conda.anaconda.org/conda-forge/
# pyyaml                         6.0.3              py313h3dea7bd_1          196.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# pyzmq                          27.1.0             py312hda471dd_2          206.6 KiB   conda  https://conda.anaconda.org/conda-forge/
# qhull                          2020.2             h434a139_5               540 KiB     conda  https://conda.anaconda.org/conda-forge/
# rav1e                          0.8.1              h1fbca29_0               5.3 MiB     conda  https://conda.anaconda.org/conda-forge/
# readline                       8.3                h853b02a_0               337 KiB     conda  https://conda.anaconda.org/conda-forge/
# referencing                    0.37.0             pyhcf101f3_0             50.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# requests                       2.33.1             pyhcf101f3_1             62.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# rfc3339-validator              0.1.4              pyhd8ed1ab_1             10 KiB      conda  https://conda.anaconda.org/conda-forge/
# rfc3986-validator              0.1.1              pyh9f0ad1d_0             7.6 KiB     conda  https://conda.anaconda.org/conda-forge/
# rfc3987-syntax                 1.1.0              pyhe01879c_1             22.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# rpds-py                        0.30.0             py313h843e2db_0          374.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# ruamel_yaml                    0.19.1                                                  pypi
# s2n                            1.7.2              hc5a330e_1               378.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# scikit-image                   0.25.2             py313h08cd8bf_2          10.3 MiB    conda  https://conda.anaconda.org/conda-forge/
# scikit_learn                   1.8.0                                                   pypi
# scipy                          1.17.1             py313h4b8bb8b_0          16.3 MiB    conda  https://conda.anaconda.org/conda-forge/
# send2trash                     2.1.0              pyha191276_1             23.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# setuptools                     82.0.1             pyh332efcf_0             624.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# six                            1.17.0             pyhe01879c_1             18 KiB      conda  https://conda.anaconda.org/conda-forge/
# snappy                         1.2.2              h03e3b7b_1               44.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# sniffio                        1.3.1              pyhd8ed1ab_2             15.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# soupsieve                      2.8.3              pyhd8ed1ab_0             37.3 KiB    conda  https://conda.anaconda.org/conda-forge/
# stack_data                     0.6.3              pyhd8ed1ab_1             26.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# svmbir                         0.4.0              py313h536fd9c_3          225.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# svt-av1                        4.0.1              hecca717_0               2.5 MiB     conda  https://conda.anaconda.org/conda-forge/
# tbb                            2023.0.0                                                pypi
# tcmlib                         1.5.0                                                   pypi
# terminado                      0.18.1             pyhc90fa1f_1             24.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# threadpoolctl                  3.6.0                                                   pypi
# tifffile                       2025.1.10          pyhd8ed1ab_0             176.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# timepix_geometry_correction    0.2.0.dev110                                            pypi   git+https://github.com/ornlneutronimaging/timepix_geometry_correction.git?branch=main#88728c2e50806e104fffa41001e3f515073788a7
# tinycss2                       1.4.0              pyhd8ed1ab_0             27.6 KiB    conda  https://conda.anaconda.org/conda-forge/
# tk                             8.6.13             noxft_h366c992_103       3.1 MiB     conda  https://conda.anaconda.org/conda-forge/
# tomli                          2.4.1              pyhcf101f3_0             21.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# tomopy                         1.15.3             pyhd8ed1ab_1             3 MiB       conda  https://conda.anaconda.org/conda-forge/
# toolz                          1.1.0                                                   pypi
# tornado                        6.5.5              py313h07c4f96_0          862.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# tqdm                           4.67.3             pyh8f84b5b_0             91.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# traitlets                      5.15.0             pyhcf101f3_0             112.5 KiB   conda  https://conda.anaconda.org/conda-forge/
# trove_classifiers              2026.4.28.13                                            pypi
# typing-extensions              4.15.0             h396c80c_0               89.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# typing-inspection              0.4.2              pyhcf101f3_2             20.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# typing_extensions              4.15.0             pyhcf101f3_0             50.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# typing_utils                   0.1.0              pyhd8ed1ab_1             14.8 KiB    conda  https://conda.anaconda.org/conda-forge/
# tzdata                         2025c              hc9c84f9_1               116.3 KiB   conda  https://conda.anaconda.org/conda-forge/
# umf                            1.1.0                                                   pypi
# uri-template                   1.3.0              pyhd8ed1ab_1             23.4 KiB    conda  https://conda.anaconda.org/conda-forge/
# urllib3                        2.6.3              pyhd8ed1ab_0             100.8 KiB   conda  https://conda.anaconda.org/conda-forge/
# wcwidth                        0.7.0              pyhd8ed1ab_0             81 KiB      conda  https://conda.anaconda.org/conda-forge/
# webcolors                      25.10.0            pyhd8ed1ab_0             18.5 KiB    conda  https://conda.anaconda.org/conda-forge/
# webencodings                   0.5.1              pyhd8ed1ab_3             15.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# websocket-client               1.9.0              pyhd8ed1ab_0             60 KiB      conda  https://conda.anaconda.org/conda-forge/
# widgetsnbextension             4.0.15             pyhd8ed1ab_0             868.4 KiB   conda  https://conda.anaconda.org/conda-forge/
# xarray                         2026.4.0           pyhc364b38_0             994.1 KiB   conda  https://conda.anaconda.org/conda-forge/
# xorg-libxau                    1.0.12             hb03c661_1               15 KiB      conda  https://conda.anaconda.org/conda-forge/
# xorg-libxdmcp                  1.1.5              hb03c661_1               20.1 KiB    conda  https://conda.anaconda.org/conda-forge/
# yaml                           0.2.5              h280c20c_3               83.2 KiB    conda  https://conda.anaconda.org/conda-forge/
# zeromq                         4.3.5              h41580af_10              303.9 KiB   conda  https://conda.anaconda.org/conda-forge/
# zfp                            1.0.1              h909a3a2_5               271.2 KiB   conda  https://conda.anaconda.org/conda-forge/
# zipp                           3.23.1             pyhcf101f3_0             23.9 KiB    conda  https://conda.anaconda.org/conda-forge/
# zlib-ng                        2.3.3              hceb46e0_1               119.7 KiB   conda  https://conda.anaconda.org/conda-forge/
# zstd                           1.5.7              hb78ec9c_6               587.3 KiB   conda  https://conda.anaconda.org/conda-forge/
