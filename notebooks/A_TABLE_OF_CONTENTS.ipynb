# %% [markdown]
# # Which notebook to use for your data ?

# %% [markdown]
# # <font color='red'>Step 1: time of flight CT (with timepix detectors)</font>
#
# For data acquired with timepix1 or timepix3
#
# <img src="__code/__all/time_of_flight_projections.png">
#
# ### <font color='red'>click here </font> ---> [step1 prepare Timepix images](step1_prepare_TimePix_images.ipynb) <---
#
# <hr>
#
# # <font color='red'>Step 1: white beam CT (with CCD detector, QHY detector ...)</font>
#
# For data acquired using CCD detectors, at VENUS or MARS
#
# <img src="__code/__all/white_beam_projections.png">
#
# ### <font color='red'>click here</font> ---> [step1 prepare CCD images](step1_prepare_CCD_images.ipynb) <---
#
# <hr style="border: none; border-top: 3px double black;">
#
# # <font color='red'>Step 2: Parallel processing (when using large detectors)</font>
#
# To divide the jobs in several smaller reconstruction
#
# <img src="__code/__all/step2-diagram.png">
#
# ### <font color='red'>click here</font> ---> [step2 slice CCD or TimePix images](step2_slice_CCD_or_TimePix_images.ipynb) <---
